# %% [markdown]
# # Karpathy — Episode 1: Building micrograd
#
# Type-along of [The spelled-out intro to neural networks and backpropagation: building micrograd](https://www.youtube.com/watch?v=VMj-3S1tku0).
#
# Reference: [karpathy/nn-zero-to-hero/lectures/micrograd](https://github.com/karpathy/nn-zero-to-hero/tree/master/lectures/micrograd) — keep this closed unless stuck.
#
# **Workflow:** pause video → think → type → run → unpause. Add notes in markdown cells when something surprises you.

# %% [markdown]
# ## 1. Derivative refresher
#
# Sliding `h → 0`, slope of a function at a point, numerical derivative.

# %% [markdown]
# ## 2. The `Value` class — wrapping a scalar
#
# Tracks `data`, `_children`, `_op`, `label`, `grad`.

# %% [markdown]
# ## 3. Building an expression graph (forward pass)
#
# Compose `Value`s with `+`, `*` and watch `_children` / `_op` populate.

# %% [markdown]
# ## 4. Visualizing the graph (graphviz)
#
# `trace` + `draw_dot` helpers.

# %% [markdown]
# ## 5. Manual backprop
#
# Compute `.grad` by hand at each node. Build the chain-rule intuition before automating.

# %% [markdown]
# ## 6. Automatic backprop — `_backward` per operation
#
# Attach a closure to each node that knows how to push gradients to its children.

# %% [markdown]
# ## 7. Topological sort + `.backward()`
#
# Walk the graph in dependency order so every parent's gradient is ready when its `_backward` runs.

# %% [markdown]
# ## 8. More ops — `tanh`, `exp`, `**`, division, subtraction
#
# Add the operations needed for a real neuron.

# %% [markdown]
# ## 9. PyTorch comparison
#
# Same expression with `torch.Tensor(..., requires_grad=True)`. Confirm gradients match.

# %% [markdown]
# ## 10. A single `Neuron`
#
# `w · x + b`, then `tanh`. Same recipe as the SGD walkthrough in `hands-on-ml/notebooks/03_classification.ipynb`.

# %% [markdown]
# ## 11. A `Layer` (list of neurons)

# %% [markdown]
# ## 12. An `MLP` (list of layers)

# %% [markdown]
# ## 13. Training loop — toy dataset
#
# 4 examples, mean-squared-error loss. Forward → loss → backward → update. Watch the loss drop.

# %% [markdown]
# ## 14. The `zero_grad` bug
#
# Karpathy's classic gotcha — gradients accumulate across iterations unless reset. Note where it bites and how to fix.

# %% [markdown]
# ## Notes / open questions
#
# Capture anything that surprised you, didn't click, or you want to come back to.
